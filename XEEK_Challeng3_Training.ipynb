# %%
## get train files
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1fuaPrB210tMS3bYhAr9I2JIsXyjcuYgC' -O train.csv
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1oIXTEvLlr7WSe28c9E_HWuowZE5bnq7q' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1oIXTEvLlr7WSe28c9E_HWuowZE5bnq7q" -O trainImages.zip && rm -rf /tmp/cookies.txt
# !ls -ltr .
# Out:
# --2020-03-05 17:53:13--  https://docs.google.com/uc?export=download&id=1fuaPrB210tMS3bYhAr9I2JIsXyjcuYgC
# Resolving docs.google.com (docs.google.com)... 74.125.202.138, 74.125.202.102, 74.125.202.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.202.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-5k-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/saad6ujh1khuhu0oralp8knebp4usd1i/1583430750000/04893697000438917423/*/1fuaPrB210tMS3bYhAr9I2JIsXyjcuYgC?e=download [following]
# ...
# --2020-03-05 17:53:19--  https://doc-00-5k-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/saad6ujh1khuhu0oralp8knebp4usd1i/1583430750000/04893697000438917423/*/1fuaPrB210tMS3bYhAr9I2JIsXyjcuYgC?e=download
# Resolving doc-00-5k-docs.googleusercontent.com (doc-00-5k-docs.googleusercontent.com)... 173.194.74.132, 2607:f8b0:4001:c0d::84
# ...

# %%
#unzip train images into its folders
# !unzip -o trainImages.zip -d ./train/ 
# !ls  ./train/*.png | wc -l
# !ls -ltr .
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./train/d55e44813d.png
#   inflating: ./train/d56379b829.png
#   inflating: ./train/d5651a0ae4.png
#   inflating: ./train/d565889c28.png
#   inflating: ./train/d5659921e8.png
#   inflating: ./train/d566870d7c.png
#   inflating: ./train/d568b9cd0b.png
#   inflating: ./train/d569b2cd8d.png
#   inflating: ./train/d56cd7fe82.png
#   inflating: ./train/d5799c5b2f.png
#   inflating: ./train/d57bcea7bb.png
#   inflating: ./train/d57c5e50fe.png
#   inflating: ./train/d57d481198.png
#   inflating: ./train/d57f9a146f.png
#   inflating: ./train/d581366d77.png
#   inflating: ./train/d58168a636.png
#   inflating: ./train/d581e53ac4.png
#   inflating: ./train/d587811568.png
#   inflating: ./train/d58814b32c.png
#   inflating: ./train/d589a8ee74.png
#   inflating: ./train/d58a26d033.png
#   inflating: ./train/d592e57c5e.png
#   inflating: ./train/d594e0c5dc.png
#   inflating: ./train/d594e3bf30.png
# ...

# %%
import pandas as pd
from glob import glob
from IPython.display import Image
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np 
from sklearn.metrics import mean_squared_error
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
import tensorflow as tf
print(tf.__version__)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0

# %%
##Read train csv file
trainDF = pd.read_csv("./train.csv")
trainDF.drop(columns=["Unnamed: 0"],inplace=True)
print(trainDF.head())
# Out:
#            id   llcrnrlon  llcrnrlat   urcrnrlon  urcrnrlat
# 0  aa5b6e01eb   52.635221  21.939847   60.276093  28.262239
# 1  e5a3b9d07d  123.974550  -6.746330  129.139013  -0.813028
# 2  3d7cedf92f  106.033993  10.328013  112.494841  18.005732
# 3  6f2fdf0368   54.051684  22.264178   59.123211  26.997385
# 4  5addc798b4  -40.403236  62.752617  -26.507330  70.153543

# %%
# !ls -ltr .
# Out:
# total 6280472
# drwxr-xr-x 1 root root       4096 Mar  3 18:11 sample_data
# -rw-r--r-- 1 root root    2771076 Mar  5 17:53 train.csv
# -rw-r--r-- 1 root root 6427400840 Mar  5 18:04 trainImages.zip
# drwxr-xr-x 2 root root    1019904 Mar  5 18:07 train

# %%
fftrain =  glob("./train/*.png")
img = cv.imread(fftrain[0])
plt.imshow(img)
plt.show()

# %%
### set parameters here or have yml file

# %%
### define your models here and replace with random generation number 
import time 
startTrainingTime = time.time()
##Write training here
##build and train your model here
##save your model here as h5/pb/pickle or anything binary format to load easily 
## on the inference notebook
##Example of saving model in tensorflow keras:
## tf.keras.models.save_model(
#    model, filepath, overwrite=True, include_optimizer=True, save_format=None,
#    signatures=None, options=None)
## https://www.tensorflow.org/api_docs/python/tf/keras/models/save_model
##Make sure to store your model files (E.g. if you use neural network, save weights)
print("Training took ", time.time()-startTrainingTime)
# Out:
# Training took  5.030632019042969e-05

# %%
## Then go to inference notebook and run the trained model there and submit both files along with submission.csv
